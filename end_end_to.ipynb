# %% [markdown]
# <a href="https://colab.research.google.com/github/CARLOX62/Simple-Linear-Regression/blob/main/end_end_to.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv("/content/placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# Steps

 # 0. Preprocess + EDA + Feature Selection
 # 1. Extract input and output cols
 # 2. Scale the values
 # 3. Train test split
 # 4. Train the model
 # 5. Evalute the model/model selection
 # 6. Deploy the model

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_test_split(x,y,test_size=0.1)
# Out:
# [    cgpa     iq
#  78   6.1   81.0
#  82   6.5   37.0
#  79   6.5   90.0
#  9    5.1   66.0
#  89   4.9  151.0
#  ..   ...    ...
#  45   6.0   66.0
#  29   7.0  112.0
#  34   4.8  163.0
#  81   5.4  107.0
#  46   5.3  114.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  53   8.3  168.0
#  54   6.4  141.0
#  56   6.1   65.0
#  27   6.0  124.0
#  92   5.2  110.0
#  2    5.3  121.0
#  72   7.3  116.0
#  26   7.0  199.0
#  7    5.0   63.0
#  47   5.2  161.0,
#  78    0
#  82    1
#  79    1
#  9     0
#  89    0
#       ..
#  45    1
#  29    1
#  34    0
#  81    0
#  46    0
#  Name: placement, Length: 90, dtype: int64,
#  53    1
#  54    1
#  56    0
#  27    1
#  92    0
#  2     0
#  72    1
#  26    1
#  7     0
#  47    0
#  Name: placement, dtype: int64]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 30   7.6  128.0
# 54   6.4  141.0
# 26   7.0  199.0
# 19   5.2  132.0
# 16   5.2  224.0
# ..   ...    ...
# 62   6.0  102.0
# 70   6.3  127.0
# 6    5.7  143.0
# 80   4.9  196.0
# 51   4.8  141.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 30    1
# 54    1
# 26    1
# 19    0
# 16    0
#      ..
# 62    0
# 70    1
# 6     0
# 80    0
# 51    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 74   6.7  154.0
# 37   8.1  149.0
# 53   8.3  168.0
# 33   6.0  149.0
# 88   4.4  149.0
# 50   3.5  233.0
# 75   4.8  169.0
# 77   7.3   50.0
# 38   6.5  160.0
# 12   5.4  139.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.48878404,  0.19846308],
#        [ 0.38673691,  0.53893493],
#        [ 0.93776047,  2.05796319],
#        [-0.71531022,  0.30322365],
#        [-0.71531022,  2.71271675],
#        [ 0.75408595,  0.53893493],
#        [ 0.11122513, -1.03247362],
#        [-0.25612392,  1.27225892],
#        [ 0.75408595, -0.2205792 ],
#        [ 0.75408595,  0.06751237],
#        [-0.5316357 , -0.16819891],
#        [ 1.21327225,  0.43417436],
#        [-1.26633378,  0.66988564],
#        [-1.54184556,  2.08415334],
#        [ 1.85613308, -1.0848539 ],
#        [ 0.47857417, -2.18483988],
#        [-1.4500083 , -2.05388917],
#        [ 0.11122513, -0.45629048],
#        [-0.990822  ,  0.90559693],
#        [ 0.57041143,  0.4603645 ],
#        [ 1.94797034,  1.19368849],
#        [-0.25612392,  0.30322365],
#        [ 0.93776047, -1.47770604],
#        [-0.16428666,  0.56512507],
#        [-1.17449652,  0.01513208],
#        [ 0.29489965, -0.45629048],
#        [-1.90919461, -0.29914963],
# ...

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.66224869,  0.87940678],
#        [ 1.94797034,  0.74845607],
#        [ 2.13164486,  1.24606878],
#        [ 0.01938787,  0.74845607],
#        [-1.4500083 ,  0.74845607],
#        [-2.27654365,  2.94842804],
#        [-1.08265926,  1.27225892],
#        [ 1.21327225, -1.84436803],
#        [ 0.47857417,  1.03654764],
#        [-0.5316357 ,  0.48655465]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# Model Training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 74    1
# 37    1
# 53    1
# 33    0
# 88    0
# 50    0
# 75    0
# 77    1
# 38    1
# 12    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values,clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
